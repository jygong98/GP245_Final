# %% [markdown]
# # test1 P (crust + mantle) — Hybrid Wavefield & Receiver Functions
#
# Single-layer crust over mantle, P-wave incidence.
#
# Benchmark: Maps to `benchmark/test1_P_out` (FDFK2D test1, Moho at 35 km, P incident).
#
# Same figure suite as `examples/Antarctica_RF`:
# `velocity_model_sections.png`, `vp_model_section.png`, `vs_model_section.png`,
# `wavefield_snapshots.png`, `wavefield_uz.gif`, `receiver_waveforms.png`,
# moveout gathers, SAC-style RF sections, 1D-ID RF profile.
#
# Run all cells, or execute `python run_workflow.py` from this folder.

# %%
import sys
from pathlib import Path

EXAMPLE_DIR = Path(".").resolve()
PROJECT_ROOT = EXAMPLE_DIR.parent.parent
sys.path.insert(0, str(PROJECT_ROOT))
sys.path.insert(0, str(PROJECT_ROOT / "examples" / "_common"))

from rf_example_workflow import ExampleConfig, run_example_workflow

CFG = ExampleConfig(
    case_name="test1_P_out",
    title_label="test1 P (crust + mantle)",
    vs_depth_max_km=50.0,
    bwf_pad_factor=2.0,  # anti-wraparound: synthesise on ~2x time axis
    force_regen=False,
    force_snapshot_regen=False,
)
print(f"Example: {EXAMPLE_DIR.name}")
print(f"Case: {CFG.case_name}")
# Out:
# Example: 1_Crust_Mantle_P
# Case: test1_P_out

# %%
run_example_workflow(EXAMPLE_DIR, CFG)
# Out:
# Project root : /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python
# Example dir  : /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python/examples/1_Crust_Mantle_P
# Model input  : /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python/examples/1_Crust_Mantle_P/cache/test1_P_out/input
# Grid: nx=1001, nz=251, nt=4001, source=P-wave f0=1.0 Hz
# Saved /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python/examples/1_Crust_Mantle_P/vs_model_section.png
# Loading cached seismograms from /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python/examples/1_Crust_Mantle_P/cache
# Loading cached snapshots from /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python/examples/1_Crust_Mantle_P/cache/snapshots
# Snapshots available: 41
# Saved /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python/examples/1_Crust_Mantle_P/wavefield_snapshots.png
# Found 41 uz snapshot files in /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python/examples/1_Crust_Mantle_P/cache/snapshots
#   Grid: x=[0, 200000] m, z=[0, 50000] m, dx=200 m, dz=200 m
#   Snapshot shape (plotted): nz=250, nx=1001 (dropped 1 surface row(s))
# Saved animation to /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python/examples/1_Crust_Mantle_P/wavefield_uz.gif
# Saved /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python/examples/1_Crust_Mantle_P/wavefield_uz.gif
# Saved /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python/examples/1_Crust_Mantle_P/receiver_waveforms.png
# Saved /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python/examples/1_Crust_Mantle_P/moveout_uz.png
# Saved /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python/examples/1_Crust_Mantle_P/moveout_ux.png
# Loaded cached RF from /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python/examples/1_Crust_Mantle_P/receiver_functions.npz
# Saved /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python/examples/1_Crust_Mantle_P/rf_section_sac.png
# Loaded cached 1D-ID RF from /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python/examples/1_Crust_Mantle_P/receiver_functions_1d_id.npz
# Saved /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python/examples/1_Crust_Mantle_P/rf_section_1d_id.png
# Saved /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python/examples/1_Crust_Mantle_P/rf_single_mid.png
#
# All figures written to: /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python/examples/1_Crust_Mantle_P
