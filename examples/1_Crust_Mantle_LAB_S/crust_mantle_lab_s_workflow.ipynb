# %% [markdown]
# # test1 S (crust + mantle to 50 km) — Hybrid Wavefield & Receiver Functions
#
# Single-layer crust over mantle to 50 km depth, S-wave incidence.
#
# Benchmark: Maps to `benchmark/test1_S_out` (FDFK2D test1, Moho at 35 km, S incident). Grid depth 50 km approximates upper-mantle/LAB-scale imaging; no deeper LAB benchmark is available.
#
# Same figure suite as `examples/Antarctica_RF`:
# `velocity_model_sections.png`, `vp_model_section.png`, `vs_model_section.png`,
# `wavefield_snapshots.png`, `wavefield_uz.gif`, `receiver_waveforms.png`,
# moveout gathers, SAC-style RF sections, 1D-ID RF profile.
#
# Run all cells, or execute `python run_workflow.py` from this folder.

# %%
import sys
from pathlib import Path

EXAMPLE_DIR = Path(".").resolve()
PROJECT_ROOT = EXAMPLE_DIR.parent.parent
sys.path.insert(0, str(PROJECT_ROOT))
sys.path.insert(0, str(PROJECT_ROOT / "examples" / "_common"))

from rf_example_workflow import ExampleConfig, run_example_workflow

CFG = ExampleConfig(
    case_name="test1_S_out",
    title_label="test1 S (crust + mantle to 50 km)",
    vs_depth_max_km=50.0,
    bwf_pad_factor=2.0,  # anti-wraparound: synthesise on ~2x time axis
    force_regen=True,
    force_snapshot_regen=True,
)
print(f"Example: {EXAMPLE_DIR.name}")
print(f"Case: {CFG.case_name}")
# Out:
# Example: 1_Crust_Mantle_LAB_S
# Case: test1_S_out

# %%
run_example_workflow(EXAMPLE_DIR, CFG)
# Out:
# Project root : /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python
# Example dir  : /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python/examples/1_Crust_Mantle_LAB_S
# Model input  : /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python/examples/1_Crust_Mantle_LAB_S/cache/test1_S_out/input
# Grid: nx=1001, nz=251, nt=4001, source=S-wave f0=1.0 Hz
# Saved /Users/jygong/Stanford/Courses/GP245 Computational Earthsystem Analysis/Final Project/FDFK_Python/examples/1_Crust_Mantle_LAB_S/vs_model_section.png
# Running compute_hybrid_seismograms (seismograms + snapshots, Numba fused loop, interval=100)...
# [Hybrid] Computing FK background wavefield (nz=251, nx=1001, nt=4001)...
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
